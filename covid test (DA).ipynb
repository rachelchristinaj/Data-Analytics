# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Rachel Christina J/Downloads/corona_tested_individuals_ver_00229.csv")

# %%
df
# Out:
#           test_date  cough  fever  sore_throat  shortness_of_breath  \
# 0        03-03-2022      0      0            0                    0
# 1        03-03-2022      0      0            0                    0
# 2        03-03-2022      0      0            0                    0
# 3        03-03-2022      0      0            0                    0
# 4        03-03-2022      0      0            0                    0
# ...             ...    ...    ...          ...                  ...
# 1048570  30-12-2021      0      0            0                    0
# 1048571  30-12-2021      0      0            0                    0
# 1048572  30-12-2021      0      0            0                    0
# 1048573  30-12-2021      0      0            0                    0
# 1048574  30-12-2021      0      0            0                    0
#
#          head_ache corona_result age_60_and_above  gender test_indication
# 0                0      positive               No  female           Other
# ...

# %%
df.head()
# Out:
#     test_date  cough  fever  sore_throat  shortness_of_breath  head_ache  \
# 0  03-03-2022      0      0            0                    0          0
# 1  03-03-2022      0      0            0                    0          0
# 2  03-03-2022      0      0            0                    0          0
# 3  03-03-2022      0      0            0                    0          0
# 4  03-03-2022      0      0            0                    0          0
#
#   corona_result age_60_and_above  gender test_indication
# 0      positive               No  female           Other
# 1      positive               No    male           Other
# 2      positive               No    male           Other
# 3      positive               No  female           Other
# 4      positive               No  female          Abroad

# %%
df.describe()
# Out:
#               cough         fever   sore_throat  shortness_of_breath  \
# count  1.048575e+06  1.048575e+06  1.048575e+06         1.048575e+06
# mean   2.640345e-02  1.177407e-02  1.363756e-02         1.141549e-03
# std    1.603320e-01  1.078678e-01  1.159810e-01         3.376755e-02
# min    0.000000e+00  0.000000e+00  0.000000e+00         0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00         0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00         0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00         0.000000e+00
# max    1.000000e+00  1.000000e+00  1.000000e+00         1.000000e+00
#
#           head_ache
# count  1.048575e+06
# mean   1.523592e-02
# std    1.224900e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.000000e+00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 10 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   test_date            1048575 non-null  object
#  1   cough                1048575 non-null  int64
#  2   fever                1048575 non-null  int64
#  3   sore_throat          1048575 non-null  int64
#  4   shortness_of_breath  1048575 non-null  int64
#  5   head_ache            1048575 non-null  int64
#  6   corona_result        1017253 non-null  object
#  7   age_60_and_above     1001316 non-null  object
#  8   gender               941394 non-null   object
#  9   test_indication      1048575 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 80.0+ MB

# %%
df.isnull().sum()
# Out:
# test_date                   0
# cough                       0
# fever                       0
# sore_throat                 0
# shortness_of_breath         0
# head_ache                   0
# corona_result           31322
# age_60_and_above        47259
# gender                 107181
# test_indication             0
# dtype: int64

# %%
df['test_indication'] = df['test_indication'].astype(str)
df ["test_indication"] = df["test_indication"].str.replace ('other', 'unkown')
df
# Out:
#           test_date  cough  fever  sore_throat  shortness_of_breath  \
# 0        03-03-2022      0      0            0                    0
# 1        03-03-2022      0      0            0                    0
# 2        03-03-2022      0      0            0                    0
# 3        03-03-2022      0      0            0                    0
# 4        03-03-2022      0      0            0                    0
# ...             ...    ...    ...          ...                  ...
# 1048570  30-12-2021      0      0            0                    0
# 1048571  30-12-2021      0      0            0                    0
# 1048572  30-12-2021      0      0            0                    0
# 1048573  30-12-2021      0      0            0                    0
# 1048574  30-12-2021      0      0            0                    0
#
#          head_ache corona_result age_60_and_above  gender test_indication
# 0                0      positive               No  female             nan
# ...

# %%
ax = sns.countplot(data = df , x = "gender")
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # From above analysis Females are more affected than males

# %%
gb = df.groupby("corona_result").agg({"cough":'mean',"fever":'mean',"sore_throat" :'mean', "shortness_of_breath":'mean', "head_ache":'mean'})
gb
# Out:
#                   cough     fever  sore_throat  shortness_of_breath  head_ache
# corona_result
# negative       0.008990  0.004089     0.004398             0.000296   0.005008
# positive       0.055802  0.024742     0.029114             0.002571   0.032400

# %%
sns.heatmap(gb, annot = True)
plt.show()

# %%
gb2 = df.groupby("test_indication").agg({"cough":'mean',"fever":'mean',"sore_throat" :'mean', "shortness_of_breath":'mean', "head_ache":'mean'})
gb2
# Out:
#                     cough     fever  sore_throat  shortness_of_breath  \
# test_indication
# nan              0.026403  0.011774     0.013638             0.001142
#
#                  head_ache
# test_indication
# nan               0.015236

# %%
sns.heatmap(gb2, annot = True)
plt.show()

# %%
sns.boxplot(data = df,x=("head_ache"),y=("cough"))
plt.show()

# %%
df["corona_result"].unique()
# Out:
# array(['positive', 'negative', nan], dtype=object)

# %%
positive = df.loc[(df['corona_result'] == 'positive')].count()
negative = df.loc[(df['corona_result'] == 'negative')].count()
l= ["negative", "positive"]
mlist= [positive['corona_result'], negative['corona_result']]
plt.pie(mlist, labels = l, autopct = "%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1e299615710>,
# ...
#  [Text(0.41576732671932165, 1.0183994943207058, 'negative'),
#   Text(-0.415767326719322, -1.0183994943207055, 'positive')],
#  [Text(0.22678217821053906, 0.5554906332658394, '37.66%'),
#   Text(-0.22678217821053923, -0.5554906332658394, '62.34%')])

# %%
ax=sns.countplot(data=df, x='corona_result')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '383120'), Text(0, 0, '634133')]
